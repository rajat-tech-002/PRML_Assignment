# %%
import numpy as np
import h5py 
f = h5py.File('faceimages.mat','r') 
data = f.get('data') 
data = np.array(data)

# %%
data=data.T

# %%
X=np.zeros((400,10304))
label=np.zeros([400,1])
for i in range(400):
    X[i]=data[i][0:10304]
    label[i]=data[i][10304]

# %%
X.shape, label.shape
# Out:
# ((400, 10304), (400, 1))

# %%
temp=X[250]
temp=np.expand_dims(temp,axis=1)
temp.shape
# Out:
# (10304, 1)

# %%
temp=temp.reshape(92,112)

# %%
import matplotlib.pyplot as plt
plt.imshow(temp)
